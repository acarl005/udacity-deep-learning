# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3083, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'originated', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 200 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/gpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.156365
# Nearest to world: biomass, tears, royston, diskette, insensible, overcomes, brie, yana,
# Nearest to many: rowan, zr, embroidery, tidy, devised, alteration, sincerely, ikeda,
# Nearest to th: columbia, interdisciplinarity, cached, rio, rpm, workgroups, riso, ox,
# Nearest to new: oriental, continent, swamped, ezra, inning, privy, kennedy, bailey,
# Nearest to these: classically, pickle, dons, eaton, lizzy, wish, bubbled, status,
# Nearest to four: horticultural, spartan, indicators, preferable, mocks, arbitral, simo, tsuburaya,
# Nearest to use: wouldn, sheba, amaziah, mythical, dwellers, pete, hiatus, inaccuracy,
# Nearest to than: tero, macao, smelling, css, inhibitory, illiterate, titanium, slaughtered,
# Nearest to their: linear, intermediate, beehives, contacting, pogo, brant, moldovans, appellations,
# Nearest to called: starring, drinkers, amarna, traceable, bevel, xx, caapi, tail,
# Nearest to people: hippocratic, organisation, manic, comfortably, tabulated, sybase, acceptors, gatt,
# Nearest to between: espa, anni, arianespace, hoffer, lysosome, raise, sauron, schweitzer,
# Nearest to would: longhorn, penultimate, destruction, harmala, tanenbaum, spivak, stabilizers, wrongfully,
# Nearest to its: alerted, medications, calculator, blanton, braking, pebble, culver, khanum,
# Nearest to by: midfielders, michaels, lf, proctor, blasphemy, theodora, six, willingness,
# Nearest to some: atherosclerosis, risked, affine, answered, html, evangelista, kidnap, quo,
# Average loss at step 2000: 4.392723
# Average loss at step 4000: 3.892513
# Average loss at step 6000: 3.812273
# Average loss at step 8000: 3.771264
# Average loss at step 10000: 3.620669
# Nearest to world: altaic, biomass, somme, microfilm, kornbluth, revolved, royston, illyrian,
# Nearest to many: esters, embroidery, all, devised, syllabus, uralic, isn, leeds,
# Nearest to th: six, seven, columbia, eight, interdisciplinarity, rio, ox, nine,
# Nearest to new: oriental, swamped, kennedy, inning, continent, privy, carefree, phanerozoic,
# Nearest to these: classically, some, pickle, egypt, all, passover, angie, many,
# Nearest to four: seven, three, five, six, eight, zero, two, nine,
# Nearest to use: sheba, wouldn, dwellers, amaziah, mythical, casta, csce, carinthia,
# Nearest to than: inhibitory, laga, smelling, physiol, tero, gastrointestinal, inflatable, harbours,
# Nearest to their: his, the, linear, its, intermediate, moldovans, touted, brant,
# Nearest to called: starring, handedness, amarna, alumnus, spent, mormonism, bowling, xx,
# Nearest to people: hippocratic, sybase, qq, bland, gatt, albury, acceptors, occur,
# Nearest to between: arianespace, anni, lysosome, gto, worn, sauron, badly, raise,
# Nearest to would: tanenbaum, penultimate, longhorn, can, starts, pepper, harmala, leak,
# Nearest to its: the, his, gurus, medications, dazzle, eminem, a, their,
# Nearest to by: was, with, be, in, for, and, is, as,
# Nearest to some: these, progress, quo, subscriber, consolidated, malaya, languished, portuguese,
# Average loss at step 12000: 3.587566
# Average loss at step 14000: 3.621980
# Average loss at step 16000: 3.591019
# Average loss at step 18000: 3.580376
# Average loss at step 20000: 3.553695
# Nearest to world: altaic, royston, illyrian, kornbluth, spreading, biomass, pd, yourdon,
# Nearest to many: some, several, these, all, other, syllabus, embroidery, they,
# Nearest to th: six, four, seven, signalling, associates, eight, rio, campaigns,
# Nearest to new: swamped, oriental, great, kennedy, coalition, inning, indentation, condemned,
# Nearest to these: some, many, which, all, are, classically, they, such,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to use: sheba, dwellers, freddy, wouldn, mythical, csce, subterfuge, flushing,
# Nearest to than: physiol, tero, gastrointestinal, inhibitory, accidentally, smelling, caused, fortresses,
# Nearest to their: his, its, the, her, some, alomar, these, amicable,
# Nearest to called: amarna, alumnus, handedness, spent, starring, molino, questioning, elevation,
# Nearest to people: albury, sybase, neurologic, photo, bodybuilders, newsreel, thea, others,
# Nearest to between: with, from, anni, in, lysosome, gto, arianespace, hardin,
# Nearest to would: can, will, may, tanenbaum, should, must, starts, harmala,
# Nearest to its: their, his, the, a, medications, culver, any, guppy,
# Nearest to by: be, from, was, been, in, as, for, were,
# Nearest to some: many, these, several, progress, their, all, any, malaya,
# Average loss at step 22000: 3.537381
# Average loss at step 24000: 3.440136
# Average loss at step 26000: 3.419829
# Average loss at step 28000: 3.479731
# Average loss at step 30000: 3.407684
# Nearest to world: royston, altaic, entscheidungsproblem, ample, kornbluth, colour, biomass, illyrian,
# Nearest to many: some, several, these, all, other, most, syllabus, progress,
# Nearest to th: signalling, six, rpm, nineteenth, associates, naka, rio, rodrigues,
# Nearest to new: great, oriental, coalition, sheik, effected, commedia, stats, swallowing,
# Nearest to these: some, many, several, such, their, all, which, different,
# Nearest to four: five, six, seven, eight, zero, three, nine, two,
# Nearest to use: sheba, dwellers, freddy, wouldn, subterfuge, csce, monolithic, strip,
# Nearest to than: or, tero, pcc, gastrointestinal, accidentally, overrun, inhibitory, inflatable,
# Nearest to their: his, its, the, her, these, some, any, them,
# Nearest to called: handedness, amarna, considered, caapi, austerlitz, starring, questioning, voltaic,
# Nearest to people: darwin, others, subsidised, reprising, albury, photo, medes, neurologic,
# Nearest to between: with, anni, from, lysosome, gto, worn, hardin, arianespace,
# Nearest to would: will, can, may, could, should, must, to, tanenbaum,
# Nearest to its: their, his, the, her, any, some, aeroplanes, ihra,
# Nearest to by: was, with, be, in, been, after, from, as,
# Nearest to some: many, these, several, most, this, their, all, any,
# Average loss at step 32000: 3.417831
# Average loss at step 34000: 3.440736
# Average loss at step 36000: 3.374776
# Average loss at step 38000: 3.495827
# Average loss at step 40000: 3.442650
# Nearest to world: ample, u, hussein, altaic, comprehended, illyrian, royston, biomass,
# Nearest to many: some, several, these, other, all, both, most, those,
# Nearest to th: nineteenth, rpm, six, signalling, naka, rio, seven, workgroups,
# Nearest to new: great, tariq, commedia, oriental, alphabetic, coalition, swallowing, sterility,
# Nearest to these: some, several, many, their, such, they, those, all,
# Nearest to four: five, seven, six, eight, zero, three, nine, two,
# Nearest to use: dwellers, freddy, sheba, cheats, monolithic, wouldn, bucharest, flushing,
# Nearest to than: pcc, tero, or, accidentally, gastrointestinal, and, but, for,
# Nearest to their: its, his, her, the, these, some, any, guppy,
# Nearest to called: considered, used, handedness, counsels, austerlitz, aeacus, annunzio, known,
# Nearest to people: others, children, medes, women, words, those, darwin, subsidised,
# Nearest to between: with, anni, lysosome, from, in, gto, following, sorcerers,
# Nearest to would: will, may, can, could, should, must, might, to,
# Nearest to its: their, his, the, her, aeroplanes, any, satirised, some,
# Nearest to by: be, with, strolling, been, was, midfielders, into, for,
# Nearest to some: many, these, several, this, their, various, both, most,
# Average loss at step 42000: 3.426741
# Average loss at step 44000: 3.273146
# Average loss at step 46000: 3.410589
# Average loss at step 48000: 3.434109
# Average loss at step 50000: 3.439012
# Nearest to world: u, hussein, informally, ample, persuading, schliemann, winter, kornbluth,
# Nearest to many: some, several, these, all, other, most, their, such,
# Nearest to th: six, five, seven, one, nineteenth, rpm, eight, four,
# Nearest to new: great, oriental, tariq, sheik, effected, swallowing, cpi, commedia,
# Nearest to these: some, several, many, such, they, those, their, are,
# Nearest to four: five, seven, eight, three, six, nine, two, zero,
# Nearest to use: sheba, dwellers, freddy, bucharest, morphology, cheats, monolithic, contradictory,
# Nearest to than: pcc, or, gastrointestinal, accidentally, tero, but, earthen, inflatable,
# Nearest to their: its, his, her, the, these, some, many, your,
# Nearest to called: considered, based, used, named, annunzio, dalai, known, see,
# Nearest to people: women, those, medes, children, others, darwin, words, subsidised,
# Nearest to between: with, in, within, from, lysosome, anni, among, hardin,
# Nearest to would: will, may, can, could, should, must, might, cannot,
# Nearest to its: their, his, the, her, satirised, expose, wafers, some,
# Nearest to by: with, was, when, and, from, be, for, indiscriminate,
# Nearest to some: many, several, these, any, all, most, their, this,
# Average loss at step 52000: 3.457380
# Average loss at step 54000: 3.430393
# Average loss at step 56000: 3.404645
# Average loss at step 58000: 3.282619
# Average loss at step 60000: 3.380768
# Nearest to world: u, hussein, informally, ample, turmeric, euro, european, comprehended,
# Nearest to many: some, several, these, all, those, such, most, their,
# Nearest to th: six, five, nineteenth, nine, one, three, four, eight,
# Nearest to new: great, oriental, commedia, beloved, swamped, tariq, mates, tenth,
# Nearest to these: some, many, several, they, such, those, which, are,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to use: sheba, bucharest, contradictory, cheats, schoolgirl, morphology, most, unaccustomed,
# Nearest to than: pcc, or, earthen, gastrointestinal, tero, much, inflatable, accidentally,
# Nearest to their: its, his, her, the, some, these, your, many,
# Nearest to called: named, considered, dalai, known, valerie, used, based, referred,
# Nearest to people: those, women, medes, children, others, critics, zero, person,
# Nearest to between: with, among, from, within, in, werewolves, lysosome, anni,
# Nearest to would: will, could, may, can, should, must, might, to,
# Nearest to its: their, his, the, her, satirised, some, tokugawa, an,
# Nearest to by: was, in, when, from, after, during, as, michaels,
# Nearest to some: many, several, these, all, any, their, those, most,
# Average loss at step 62000: 3.446699
# Average loss at step 64000: 3.363337
# Average loss at step 66000: 3.336998
# Average loss at step 68000: 3.385377
# Average loss at step 70000: 3.373431
# Nearest to world: turmeric, hussein, condita, informally, rw, euro, ample, winter,
# Nearest to many: some, several, all, these, most, such, both, those,
# Nearest to th: five, eight, four, seven, nineteenth, six, zero, nine,
# Nearest to new: great, beloved, oriental, swamped, carmine, commedia, palestinian, modern,
# Nearest to these: some, such, several, many, those, their, they, were,
# Nearest to four: five, six, eight, seven, three, nine, zero, two,
# Nearest to use: most, represent, blend, sheba, rapport, unaccustomed, morphology, need,
# Nearest to than: pcc, or, much, and, tero, accidentally, gastrointestinal, ais,
# Nearest to their: its, his, her, the, these, some, your, many,
# Nearest to called: named, used, considered, known, referred, based, dalai, davidic,
# Nearest to people: women, children, those, men, others, critics, medes, genders,
# Nearest to between: with, among, within, in, hardin, cour, from, anni,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to its: their, his, the, her, burrito, some, many, several,
# Nearest to by: through, was, from, with, after, were, when, midfielders,
# Nearest to some: many, several, these, most, all, both, their, any,
# Average loss at step 72000: 3.403610
# Average loss at step 74000: 3.387812
# Average loss at step 76000: 3.347370
# Average loss at step 78000: 3.231908
# Average loss at step 80000: 3.369405
# Nearest to world: turmeric, hussein, ample, law, u, nest, royston, everybody,
# Nearest to many: some, several, these, most, those, all, both, numerous,
# Nearest to th: eight, nineteenth, six, five, zero, rpm, seven, rd,
# Nearest to new: commedia, simple, sited, modern, carmine, swamped, certain, oriental,
# Nearest to these: such, some, several, many, those, both, which, they,
# Nearest to four: five, six, seven, three, eight, nine, zero, two,
# Nearest to use: most, morphology, blend, represent, unaccustomed, schoolgirl, cheats, conjugation,
# Nearest to than: or, pcc, much, accidentally, tero, while, far, cycled,
# Nearest to their: its, his, her, our, the, my, your, these,
# Nearest to called: used, named, known, based, considered, dalai, fluently, referred,
# Nearest to people: children, those, women, medes, them, others, genders, troops,
# Nearest to between: with, among, within, in, through, cour, from, gto,
# Nearest to would: will, may, could, can, should, must, might, cannot,
# Nearest to its: their, his, the, her, s, whose, ewell, jamaican,
# Nearest to by: without, from, through, on, is, with, be, as,
# Nearest to some: many, several, these, any, most, both, all, those,
# Average loss at step 82000: 3.301848
# Average loss at step 84000: 3.342453
# Average loss at step 86000: 3.343353
# Average loss at step 88000: 3.317887
# Average loss at step 90000: 3.244051
# Nearest to world: nest, hussein, law, winter, european, turmeric, ample, u,
# Nearest to many: some, several, these, those, numerous, most, all, few,
# Nearest to th: nineteenth, eight, five, one, four, two, rpm, zero,
# Nearest to new: sited, modern, functionaries, chests, commedia, nearing, oriental, great,
# Nearest to these: several, those, many, some, such, their, were, all,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Nearest to use: blend, cowan, schoolgirl, unaccustomed, cheats, hopelessly, stands, most,
# Nearest to than: or, much, pcc, no, gastrointestinal, even, far, accidentally,
# Nearest to their: its, his, her, our, my, these, your, whose,
# Nearest to called: used, named, known, based, dalai, referred, considered, fluently,
# Nearest to people: women, children, men, those, troops, medes, genders, them,
# Nearest to between: with, among, within, from, through, hain, following, in,
# Nearest to would: will, could, can, may, should, might, must, cannot,
# Nearest to its: their, his, her, the, whose, donatello, kathryn, some,
# Nearest to by: from, with, when, through, for, midfielders, ceiba, and,
# Nearest to some: many, several, these, any, most, all, various, this,
# Average loss at step 92000: 2.739950
# Average loss at step 94000: 3.090547
# Average loss at step 96000: 3.065143
# Average loss at step 98000: 3.220115
# Average loss at step 100000: 3.280434
# Nearest to world: hussein, year, european, ample, turmeric, nest, u, participant,
# Nearest to many: some, several, these, those, various, numerous, both, such,
# Nearest to th: nineteenth, four, rd, rpm, seven, nd, seventh, one,
# Nearest to new: modern, sited, beloved, oriental, great, functionaries, commedia, different,
# Nearest to these: several, many, those, some, such, are, their, his,
# Nearest to four: seven, five, six, three, eight, nine, two, zero,
# Nearest to use: support, cheats, most, blend, cause, contradictory, hopelessly, unaccustomed,
# Nearest to than: or, much, pcc, no, but, earthen, forbes, even,
# Nearest to their: its, his, her, the, our, these, your, whose,
# Nearest to called: used, named, based, referred, known, considered, annunzio, fluently,
# Nearest to people: women, children, men, those, musicians, genders, historians, others,
# Nearest to between: with, among, in, from, within, through, following, outside,
# Nearest to would: will, could, can, may, must, might, should, cannot,
# Nearest to its: their, his, her, the, whose, donatello, republika, this,
# Nearest to by: with, for, without, be, him, against, through, midfielders,
# Nearest to some: many, several, these, any, both, various, most, all,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Don't even need a new graph. Should simply have to switch the labels and the data. Predict the word from the context instead of the other way around

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    # generate the batches and labels just like before
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    # switch the variables and their shapes
    batch_labels, batch_data = (batch_data.reshape(batch_size, 1), batch_labels.reshape(batch_size,))
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.198709
# Nearest to world: arbitral, bootstrapping, plunder, mammoths, aam, taxicab, snails, internally,
# Nearest to many: hipper, genitive, psychologist, molly, hardin, sas, crony, melts,
# Nearest to th: doctrines, filtered, bureaucracy, beforehand, denial, cautions, ingenuity, enterprises,
# Nearest to new: sweetened, mules, dropped, stoney, gustavus, fay, muppets, potsdam,
# Nearest to these: ferret, itunes, mathrm, founding, occupy, kore, formatted, capone,
# Nearest to four: ibf, marshes, rensselaer, unsatisfied, barra, clinic, atanasoff, emulated,
# Nearest to use: humours, sentence, coordination, dodgers, dean, decimated, outta, metastasis,
# Nearest to than: randall, tallinn, fremen, trucks, telnet, humid, savannah, polynomials,
# Nearest to their: tetrapods, reconquer, hero, confess, sadness, globalsecurity, conserved, pinned,
# Nearest to called: detroit, formulations, redevelopment, aquarists, smyrna, grouse, awakens, imp,
# Nearest to people: teutonic, disorderly, krylov, nx, arrow, mombasa, markup, rafter,
# Nearest to between: chien, wiccan, rds, suborder, meshed, flyer, bagpipes, restroom,
# Nearest to would: pla, xinhua, backstage, ian, gottfried, weezer, modulator, truth,
# Nearest to its: oldham, verisimilitude, throughout, convertible, tanks, dreamworks, scum, handbuch,
# Nearest to by: paste, pdf, civitas, thelema, penal, henze, nitrous, kripke,
# Nearest to some: picker, raison, traitors, goidelic, fiend, psilocybin, narcolepsy, lethargy,
# Average loss at step 2000: 4.255471
# Average loss at step 4000: 3.902164
# Average loss at step 6000: 3.804494
# Average loss at step 8000: 3.746267
# Average loss at step 10000: 3.698487
# Nearest to world: bootstrapping, incorruptible, ailing, arbitral, taxicab, vesalius, sympathizers, distinctively,
# Nearest to many: some, hipper, genitive, these, hardin, cherubim, suzaku, kore,
# Nearest to th: six, doctrines, three, four, five, bureaucracy, filtered, denial,
# Nearest to new: sweetened, bedrooms, mules, fay, chifley, dropped, potsdam, lcms,
# Nearest to these: some, refounded, capone, objectively, showtime, pastures, many, mcp,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Nearest to use: humours, decimated, hei, sentence, outta, attractions, dodgers, fredrik,
# Nearest to than: or, randall, fremen, telnet, savannah, hanssen, tallinn, polynomials,
# Nearest to their: his, its, the, sadness, rectangular, a, some, uncollected,
# Nearest to called: detroit, awakens, shoot, dieu, mcmahon, avar, colette, aquarists,
# Nearest to people: teutonic, markup, freezing, champagne, disorderly, captains, piedmont, agena,
# Nearest to between: from, suborder, dalhousie, restroom, meshed, diagram, spencer, in,
# Nearest to would: will, can, modulator, pla, heiress, was, rodr, truth,
# Nearest to its: his, their, the, oldham, pka, verisimilitude, erudite, inherent,
# Nearest to by: from, was, in, and, be, for, were, on,
# Nearest to some: many, fiend, these, this, picker, their, they, raison,
# Average loss at step 12000: 3.678720
# Average loss at step 14000: 3.626769
# Average loss at step 16000: 3.415817
# Average loss at step 18000: 3.479911
# Average loss at step 20000: 3.577563
# Nearest to world: distinctively, ailing, incorruptible, bootstrapping, lector, jin, inherited, arrhythmias,
# Nearest to many: some, these, several, most, the, their, kenyon, monosodium,
# Nearest to th: five, four, six, three, doctrines, seven, eight, bureaucracy,
# Nearest to new: fay, sweetened, mules, bedrooms, chifley, guarantees, ensign, lcms,
# Nearest to these: some, such, many, they, their, several, its, showtime,
# Nearest to four: three, five, six, eight, seven, nine, zero, two,
# Nearest to use: outta, humours, decimated, sentence, attractions, hei, confidentiality, dean,
# Nearest to than: randall, or, humid, fremen, dispossessed, hanssen, wettest, griffin,
# Nearest to their: its, his, the, some, counterparts, glove, her, these,
# Nearest to called: awakens, detroit, shoot, macleod, nonviolence, jones, rebuked, aquarists,
# Nearest to people: women, piedmont, champagne, markup, panipat, teutonic, disorderly, repatriation,
# Nearest to between: from, dalhousie, suborder, encroaching, bagpipes, restroom, spencer, namco,
# Nearest to would: will, can, may, could, might, should, modulator, pla,
# Nearest to its: their, his, the, some, pka, any, engineered, these,
# Nearest to by: was, be, accordingly, in, with, been, from, into,
# Nearest to some: many, these, their, all, its, several, the, most,
# Average loss at step 22000: 3.546981
# Average loss at step 24000: 3.496963
# Average loss at step 26000: 3.517820
# Average loss at step 28000: 3.485421
# Average loss at step 30000: 3.458184
# Nearest to world: distinctively, incorruptible, mcnamara, ailing, lector, haughey, sher, arrhythmias,
# Nearest to many: some, several, these, most, other, such, various, all,
# Nearest to th: seven, bc, doctrines, three, eight, promotion, six, sabra,
# Nearest to new: bedrooms, guarantees, sweetened, mules, fay, major, potsdam, dawson,
# Nearest to these: many, some, such, all, they, those, which, their,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to use: decimated, attractions, usage, leiden, confidentiality, dean, purpose, sentence,
# Nearest to than: or, humid, telnet, randall, wettest, dispossessed, barristers, but,
# Nearest to their: its, his, the, her, some, these, repeatedly, rectangular,
# Nearest to called: used, wires, detroit, beatle, shoot, interconnect, macleod, awakens,
# Nearest to people: women, years, champagne, piedmont, repatriation, consignee, breakbeats, exercise,
# Nearest to between: from, with, spencer, in, through, dalhousie, restroom, suborder,
# Nearest to would: will, may, can, could, might, must, should, hiller,
# Nearest to its: their, the, his, pka, any, engineered, pops, inherent,
# Nearest to by: was, from, be, during, with, through, weaving, when,
# Nearest to some: many, these, most, all, several, their, both, the,
# Average loss at step 32000: 3.473347
# Average loss at step 34000: 3.474241
# Average loss at step 36000: 3.516876
# Average loss at step 38000: 3.513959
# Average loss at step 40000: 3.476215
# Nearest to world: incorruptible, sher, distinctively, haughey, yakovlev, jin, lector, mcnamara,
# Nearest to many: some, several, these, most, other, all, various, those,
# Nearest to th: seven, six, five, bc, four, eight, three, one,
# Nearest to new: guarantees, uns, major, sweetened, bedrooms, salem, mules, weu,
# Nearest to these: some, many, several, those, such, all, they, both,
# Nearest to four: seven, five, eight, three, six, nine, zero, two,
# Nearest to use: purpose, decimated, usage, attractions, confidentiality, form, rabin, hei,
# Nearest to than: or, much, humid, wettest, hanssen, exercises, randall, discs,
# Nearest to their: its, his, her, the, some, any, these, them,
# Nearest to called: used, viet, appomattox, named, shoot, expending, there, see,
# Nearest to people: women, piedmont, champagne, men, those, parents, breakbeats, consignee,
# Nearest to between: from, with, through, in, into, spencer, among, diagram,
# Nearest to would: will, can, may, could, might, should, must, to,
# Nearest to its: their, his, the, pka, any, her, some, this,
# Nearest to by: were, as, was, when, be, been, through, from,
# Nearest to some: many, these, several, most, all, their, this, both,
# Average loss at step 42000: 3.453728
# Average loss at step 44000: 3.459262
# Average loss at step 46000: 3.463573
# Average loss at step 48000: 3.358777
# Average loss at step 50000: 3.429575
# Nearest to world: incorruptible, distinctively, jin, lector, citadel, yakovlev, haughey, ailing,
# Nearest to many: some, several, these, most, all, various, those, other,
# Nearest to th: four, ad, bc, rd, mistaken, promotion, frits, afrobeat,
# Nearest to new: fay, mules, earthdawn, dawson, horst, aan, noel, weu,
# Nearest to these: some, many, several, those, they, both, all, such,
# Nearest to four: five, three, eight, seven, six, nine, two, zero,
# Nearest to use: usage, attractions, purpose, rabin, firestone, haller, aberdare, simplify,
# Nearest to than: or, much, hanssen, and, wettest, humid, no, industrialization,
# Nearest to their: its, his, her, the, our, any, some, these,
# Nearest to called: used, viet, appomattox, named, considered, unaccompanied, awakens, expending,
# Nearest to people: women, men, children, breakbeats, parents, champagne, reiner, those,
# Nearest to between: from, with, through, dalhousie, diagram, bagpipes, among, wiccan,
# Nearest to would: will, may, can, could, might, must, should, did,
# Nearest to its: their, his, the, her, any, our, some, pka,
# Nearest to by: when, with, be, from, through, civitas, henze, meningitis,
# Nearest to some: many, these, several, this, most, all, both, any,
# Average loss at step 52000: 3.329942
# Average loss at step 54000: 3.447439
# Average loss at step 56000: 3.395602
# Average loss at step 58000: 3.366166
# Average loss at step 60000: 3.452068
# Nearest to world: cold, citadel, lector, ailing, marischal, distinctively, yakovlev, crows,
# Nearest to many: some, several, these, most, all, those, various, such,
# Nearest to th: bc, one, nine, rd, eight, four, nd, seven,
# Nearest to new: major, kovacs, fay, accordions, earthdawn, mules, harms, mjw,
# Nearest to these: several, many, some, those, all, such, both, which,
# Nearest to four: six, seven, eight, five, three, nine, two, zero,
# Nearest to use: usage, haller, purpose, ease, firestone, alford, rabin, simplify,
# Nearest to than: much, or, wettest, industrialization, sutra, intergalactic, hanssen, surged,
# Nearest to their: its, his, her, our, the, your, some, these,
# Nearest to called: used, named, viet, known, appomattox, considered, strive, bckgr,
# Nearest to people: children, men, women, those, consignee, breakbeats, players, champagne,
# Nearest to between: with, through, from, in, among, within, into, liberated,
# Nearest to would: will, can, could, may, might, must, should, did,
# Nearest to its: their, his, the, her, any, pka, our, battled,
# Nearest to by: with, in, from, had, was, during, after, when,
# Nearest to some: many, several, these, most, any, all, those, the,
# Average loss at step 62000: 3.399406
# Average loss at step 64000: 3.254622
# Average loss at step 66000: 3.365472
# Average loss at step 68000: 3.372309
# Average loss at step 70000: 3.368626
# Nearest to world: country, ailing, cold, hiking, citadel, marischal, aptly, polishing,
# Nearest to many: some, several, these, various, all, those, most, both,
# Nearest to th: bc, five, seven, nd, rd, four, six, ad,
# Nearest to new: different, pumping, harms, mules, tractatus, loss, uns, collaboration,
# Nearest to these: several, many, those, some, such, both, all, they,
# Nearest to four: five, eight, six, seven, three, nine, two, zero,
# Nearest to use: usage, haller, firestone, purpose, most, cause, form, ease,
# Nearest to than: or, much, and, sutra, wettest, but, industrialization, barrels,
# Nearest to their: its, his, her, our, your, the, these, those,
# Nearest to called: named, used, appomattox, considered, strive, given, known, viet,
# Nearest to people: children, men, women, those, champagne, consignee, characters, reiner,
# Nearest to between: among, with, in, from, within, into, through, over,
# Nearest to would: will, could, may, can, might, must, should, did,
# Nearest to its: their, his, the, her, our, any, pka, some,
# Nearest to by: with, through, from, meningitis, be, weaving, for, civitas,
# Nearest to some: many, several, these, any, all, most, their, this,
# Average loss at step 72000: 3.397556
# Average loss at step 74000: 3.367628
# Average loss at step 76000: 3.383673
# Average loss at step 78000: 3.286421
# Average loss at step 80000: 3.236548
# Nearest to world: country, cold, citadel, aptly, marischal, sus, europe, renaissance,
# Nearest to many: some, several, these, those, all, various, most, both,
# Nearest to th: bc, six, seven, five, four, rd, eight, nine,
# Nearest to new: tractatus, modern, continuous, different, kitchener, real, harms, of,
# Nearest to these: several, many, some, those, such, both, they, all,
# Nearest to four: five, six, seven, eight, three, nine, zero, two,
# Nearest to use: haller, purpose, usage, confidentiality, ease, cause, constituting, francophones,
# Nearest to than: much, or, sutra, but, wettest, barrels, hanssen, randall,
# Nearest to their: its, his, her, the, our, your, any, some,
# Nearest to called: named, used, appomattox, considered, containment, known, referred, see,
# Nearest to people: those, men, children, women, consignee, members, words, administrations,
# Nearest to between: with, among, from, within, through, while, in, into,
# Nearest to would: could, may, can, will, might, should, must, did,
# Nearest to its: their, his, her, the, some, any, our, pka,
# Nearest to by: from, including, directness, weaving, in, instructive, under, him,
# Nearest to some: many, these, several, those, any, his, all, their,
# Average loss at step 82000: 3.358286
# Average loss at step 84000: 3.264634
# Average loss at step 86000: 3.280398
# Average loss at step 88000: 3.357441
# Average loss at step 90000: 3.221624
# Nearest to world: country, citadel, cold, ailing, u, however, adventure, mainstay,
# Nearest to many: some, several, various, these, those, all, both, most,
# Nearest to th: bc, one, rd, nd, six, eight, afrobeat, four,
# Nearest to new: different, tractatus, fay, clog, lest, historical, third, involvement,
# Nearest to these: several, those, some, many, they, both, such, various,
# Nearest to four: eight, six, five, seven, nine, three, two, zero,
# Nearest to use: usage, haller, purpose, cause, follow, confidentiality, alford, delacroix,
# Nearest to than: or, much, hanssen, surged, wettest, sutra, industrialization, but,
# Nearest to their: its, his, her, our, your, the, any, these,
# Nearest to called: named, used, considered, known, appomattox, referred, viet, strive,
# Nearest to people: women, men, children, those, years, members, consignee, countries,
# Nearest to between: with, in, among, from, within, through, on, into,
# Nearest to would: will, could, can, may, might, must, should, did,
# Nearest to its: their, his, her, the, our, konar, pka, stalks,
# Nearest to by: under, from, through, when, for, with, was, bunge,
# Nearest to some: many, several, these, this, any, both, all, those,
# Average loss at step 92000: 3.399455
# Average loss at step 94000: 3.334850
# Average loss at step 96000: 3.320892
# Average loss at step 98000: 3.088048
# Average loss at step 100000: 3.368519
# Nearest to world: u, country, cold, however, citadel, liberalism, aptly, adventure,
# Nearest to many: some, several, various, these, most, those, both, numerous,
# Nearest to th: bc, one, nd, ad, six, rd, four, fourth,
# Nearest to new: modern, different, collaboration, bedrooms, kovacs, mules, terabytes, race,
# Nearest to these: some, those, several, many, such, were, both, various,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to use: haller, usage, purpose, alford, example, confidentiality, follow, ease,
# Nearest to than: much, or, surged, hanssen, far, and, randall, wettest,
# Nearest to their: its, his, her, our, your, some, whose, the,
# Nearest to called: named, used, considered, appomattox, referred, known, viet, fingerprinting,
# Nearest to people: men, women, children, those, consignee, words, jews, members,
# Nearest to between: among, with, within, from, liberated, through, against, kanons,
# Nearest to would: will, could, can, might, may, must, should, did,
# Nearest to its: their, his, her, the, our, some, stalks, militaries,
# Nearest to by: was, during, when, while, through, vasili, of, after,
# Nearest to some: many, these, several, most, any, those, certain, their,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
