# %% [markdown]
# Deep Learning
# =============
#
# Assignment 1
# ------------
#
# The objective of this assignment is to learn about simple data curation practices, and familiarize you with some of the data we'll be reusing later.
#
# This notebook uses the [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) dataset to be used with python experiments. This dataset is designed to look like the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, while looking a little more like real data: it's a harder task, and the data is a lot less 'clean' than MNIST.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
import random
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
from collections import defaultdict

# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

# %% [markdown]
# First, we'll download the dataset to our local machine. The data consists of characters rendered in a variety of fonts on a 28x28 image. The labels are limited to 'A' through 'J' (10 classes). The training set has about 500k and the testset 19000 labelled examples. Given these sizes, it should be possible to train models quickly on any machine.

# %%
url = 'http://commondatastorage.googleapis.com/books1000/'
last_percent_reported = None

def download_progress_hook(count, blockSize, totalSize):
  """A hook to report the progress of a download. This is mostly intended for users with
  slow internet connections. Reports every 1% change in download progress.
  """
  global last_percent_reported
  percent = int(count * blockSize * 100 / totalSize)

  if last_percent_reported != percent:
    if percent % 5 == 0:
      sys.stdout.write("%s%%" % percent)
      sys.stdout.flush()
    else:
      sys.stdout.write(".")
      sys.stdout.flush()
      
    last_percent_reported = percent
        
def maybe_download(filename, expected_bytes, force=False):
  """Download a file if not present, and make sure it's the right size."""
  if force or not os.path.exists(filename):
    print('Attempting to download:', filename) 
    filename, _ = urlretrieve(url + filename, filename, reporthook=download_progress_hook)
    print('\nDownload Complete!')
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

train_filename = maybe_download('notMNIST_large.tar.gz', 247336696)
test_filename = maybe_download('notMNIST_small.tar.gz', 8458043)
# Out:
# Found and verified notMNIST_large.tar.gz
# Found and verified notMNIST_small.tar.gz

# %% [markdown]
# Extract the dataset from the compressed .tar.gz file.
# This should give you a set of directories, labelled A through J.

# %%
num_classes = 10
np.random.seed(133)

def maybe_extract(filename, force=False):
  root = os.path.splitext(os.path.splitext(filename)[0])[0]  # remove .tar.gz
  if os.path.isdir(root) and not force:
    # You may override by setting force=True.
    print('%s already present - Skipping extraction of %s.' % (root, filename))
  else:
    print('Extracting data for %s. This may take a while. Please wait.' % root)
    tar = tarfile.open(filename)
    sys.stdout.flush()
    tar.extractall()
    tar.close()
  data_folders = [
    os.path.join(root, d) for d in sorted(os.listdir(root))
    if os.path.isdir(os.path.join(root, d))]
  if len(data_folders) != num_classes:
    raise Exception(
      'Expected %d folders, one per class. Found %d instead.' % (
        num_classes, len(data_folders)))
  print(data_folders)
  return data_folders
  
train_folders = maybe_extract(train_filename)
test_folders = maybe_extract(test_filename)
# Out:
# notMNIST_large already present - Skipping extraction of notMNIST_large.tar.gz.
# ['notMNIST_large/A', 'notMNIST_large/B', 'notMNIST_large/C', 'notMNIST_large/D', 'notMNIST_large/E', 'notMNIST_large/F', 'notMNIST_large/G', 'notMNIST_large/H', 'notMNIST_large/I', 'notMNIST_large/J']
# notMNIST_small already present - Skipping extraction of notMNIST_small.tar.gz.
# ['notMNIST_small/A', 'notMNIST_small/B', 'notMNIST_small/C', 'notMNIST_small/D', 'notMNIST_small/E', 'notMNIST_small/F', 'notMNIST_small/G', 'notMNIST_small/H', 'notMNIST_small/I', 'notMNIST_small/J']

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Let's take a peek at some of the data to make sure it looks sensible. Each exemplar should be an image of a character A through J rendered in a different font. Display a sample of the images that we just downloaded. Hint: you can use the package IPython.display.
#
# ---

# %%
for folder_name in train_folders:
    random_image = random.choice(os.listdir(folder_name))
    display(Image(filename='%s/%s' % (folder_name, random_image)))

# %% [markdown]
# Now let's load the data in a more manageable format. Since, depending on your computer setup you might not be able to fit it all in memory, we'll load each class into a separate dataset, store them on disk and curate them independently. Later we'll merge them into a single dataset of manageable size.
#
# We'll convert the entire dataset into a 3D array (image index, x, y) of floating point values, normalized to have approximately zero mean and standard deviation ~0.5 to make training easier down the road.
#
# A few images might not be readable, we'll just skip them.

# %%
image_size = 28  # Pixel width and height.
pixel_depth = 255.0  # Number of levels per pixel.

def load_letter(folder, min_num_images):
  """Load the data for a single letter label."""
  image_files = os.listdir(folder)
  dataset = np.ndarray(shape=(len(image_files), image_size, image_size),
                         dtype=np.float32)
  print(folder)
  num_images = 0
  for image in image_files:
    image_file = os.path.join(folder, image)
    try:
      image_data = (ndimage.imread(image_file).astype(float) - 
                    pixel_depth / 2) / pixel_depth
      if image_data.shape != (image_size, image_size):
        raise Exception('Unexpected image shape: %s' % str(image_data.shape))
      dataset[num_images, :, :] = image_data
      num_images = num_images + 1
    except IOError as e:
      print('Could not read:', image_file, ':', e, '- it\'s ok, skipping.')
    
  dataset = dataset[0:num_images, :, :]
  if num_images < min_num_images:
    raise Exception('Many fewer images than expected: %d < %d' %
                    (num_images, min_num_images))
    
  print('Full dataset tensor:', dataset.shape)
  print('Mean:', np.mean(dataset))
  print('Standard deviation:', np.std(dataset))
  return dataset
        
def maybe_pickle(data_folders, min_num_images_per_class, force=False):
  dataset_names = []
  for folder in data_folders:
    set_filename = folder + '.pickle'
    dataset_names.append(set_filename)
    if os.path.exists(set_filename) and not force:
      # You may override by setting force=True.
      print('%s already present - Skipping pickling.' % set_filename)
    else:
      print('Pickling %s.' % set_filename)
      dataset = load_letter(folder, min_num_images_per_class)
      try:
        with open(set_filename, 'wb') as f:
          pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
      except Exception as e:
        print('Unable to save data to', set_filename, ':', e)
  
  return dataset_names

train_datasets = maybe_pickle(train_folders, 45000)
test_datasets = maybe_pickle(test_folders, 1800)
# Out:
# notMNIST_large/A.pickle already present - Skipping pickling.
# notMNIST_large/B.pickle already present - Skipping pickling.
# notMNIST_large/C.pickle already present - Skipping pickling.
# notMNIST_large/D.pickle already present - Skipping pickling.
# notMNIST_large/E.pickle already present - Skipping pickling.
# notMNIST_large/F.pickle already present - Skipping pickling.
# notMNIST_large/G.pickle already present - Skipping pickling.
# notMNIST_large/H.pickle already present - Skipping pickling.
# notMNIST_large/I.pickle already present - Skipping pickling.
# notMNIST_large/J.pickle already present - Skipping pickling.
# notMNIST_small/A.pickle already present - Skipping pickling.
# notMNIST_small/B.pickle already present - Skipping pickling.
# notMNIST_small/C.pickle already present - Skipping pickling.
# notMNIST_small/D.pickle already present - Skipping pickling.
# notMNIST_small/E.pickle already present - Skipping pickling.
# notMNIST_small/F.pickle already present - Skipping pickling.
# notMNIST_small/G.pickle already present - Skipping pickling.
# notMNIST_small/H.pickle already present - Skipping pickling.
# notMNIST_small/I.pickle already present - Skipping pickling.
# notMNIST_small/J.pickle already present - Skipping pickling.

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Let's verify that the data still looks good. Displaying a sample of the labels and images from the ndarray. Hint: you can use matplotlib.pyplot.
#
# ---

# %%
with open(train_datasets[0], 'rb') as f:
    a_array = pickle.loads(f.read())
    plt.imshow(a_array[0])

# %% [markdown]
# ---
# Problem 3
# ---------
# Another check: we expect the data to be balanced across classes. Verify that.
#
# ---

# %%
def show_count(datasets):
    for dataset in datasets:
        with open(dataset, 'rb') as f:
            array = pickle.loads(f.read())
            print(dataset[15], ':', len(array), 'images')

show_count(train_datasets)
print()
show_count(test_datasets)
# Out:
# A : 52909 images
# B : 52911 images
# C : 52912 images
# D : 52911 images
# E : 52912 images
# F : 52912 images
# G : 52912 images
# H : 52912 images
# I : 52912 images
# J : 52911 images
#
# A : 1872 images
# B : 1873 images
# C : 1873 images
# D : 1873 images
# E : 1873 images
# F : 1872 images
# G : 1872 images
# H : 1872 images
# I : 1872 images
# J : 1872 images

# %% [markdown]
# Merge and prune the training data as needed. Depending on your computer setup, you might not be able to fit it all in memory, and you can tune `train_size` as needed. The labels will be stored into a separate array of integers 0 through 9.
#
# Also create a validation dataset for hyperparameter tuning.

# %%
def make_arrays(nb_rows, img_size):
  if nb_rows:
    dataset = np.ndarray((nb_rows, img_size, img_size), dtype=np.float32)
    labels = np.ndarray(nb_rows, dtype=np.int32)
  else:
    dataset, labels = None, None
  return dataset, labels

def merge_datasets(pickle_files, train_size, valid_size=0):
  num_classes = len(pickle_files)
  valid_dataset, valid_labels = make_arrays(valid_size, image_size)
  train_dataset, train_labels = make_arrays(train_size, image_size)
  vsize_per_class = valid_size // num_classes
  tsize_per_class = train_size // num_classes
    
  start_v, start_t = 0, 0
  end_v, end_t = vsize_per_class, tsize_per_class
  end_l = vsize_per_class+tsize_per_class
  for label, pickle_file in enumerate(pickle_files):       
    try:
      with open(pickle_file, 'rb') as f:
        letter_set = pickle.load(f)
        # let's shuffle the letters to have random validation and training set
        np.random.shuffle(letter_set)
        if valid_dataset is not None:
          valid_letter = letter_set[:vsize_per_class, :, :]
          valid_dataset[start_v:end_v, :, :] = valid_letter
          valid_labels[start_v:end_v] = label
          start_v += vsize_per_class
          end_v += vsize_per_class
                    
        train_letter = letter_set[vsize_per_class:end_l, :, :]
        train_dataset[start_t:end_t, :, :] = train_letter
        train_labels[start_t:end_t] = label
        start_t += tsize_per_class
        end_t += tsize_per_class
    except Exception as e:
      print('Unable to process data from', pickle_file, ':', e)
      raise
    
  return valid_dataset, valid_labels, train_dataset, train_labels
            
            
train_size = 200000
valid_size = 10000
test_size = 10000

valid_dataset, valid_labels, train_dataset, train_labels = merge_datasets(
  train_datasets, train_size, valid_size)
_, _, test_dataset, test_labels = merge_datasets(test_datasets, test_size)

print('Training:', train_dataset.shape, train_labels.shape)
print('Validation:', valid_dataset.shape, valid_labels.shape)
print('Testing:', test_dataset.shape, test_labels.shape)
# Out:
# Training: (200000, 28, 28) (200000,)
# Validation: (10000, 28, 28) (10000,)
# Testing: (10000, 28, 28) (10000,)

# %% [markdown]
# Next, we'll randomize the data. It's important to have the labels well shuffled for the training and test distributions to match.

# %%
def randomize(dataset, labels):
  permutation = np.random.permutation(labels.shape[0])
  shuffled_dataset = dataset[permutation,:,:]
  shuffled_labels = labels[permutation]
  return shuffled_dataset, shuffled_labels
train_dataset, train_labels = randomize(train_dataset, train_labels)
test_dataset, test_labels = randomize(test_dataset, test_labels)
valid_dataset, valid_labels = randomize(valid_dataset, valid_labels)

# %% [markdown]
# ---
# Problem 4
# ---------
# Convince yourself that the data is still good after shuffling!
#
# ---

# %%
def sample(dataset, start, end):
    for i in range(start, end):
        plt.figure(start - i + 1)
        plt.imshow(dataset[i])
    plt.show()
    
sample(train_dataset, 4, 8)

# %% [markdown]
# Finally, let's save the data for later reuse:

# %%
pickle_file = 'notMNIST.pickle'

try:
  f = open(pickle_file, 'wb')
  save = {
    'train_dataset': train_dataset,
    'train_labels': train_labels,
    'valid_dataset': valid_dataset,
    'valid_labels': valid_labels,
    'test_dataset': test_dataset,
    'test_labels': test_labels,
    }
  pickle.dump(save, f, pickle.HIGHEST_PROTOCOL)
  f.close()
except Exception as e:
  print('Unable to save data to', pickle_file, ':', e)
  raise

# %%
statinfo = os.stat(pickle_file)
print('Compressed pickle size:', statinfo.st_size)
# Out:
# Compressed pickle size: 690800441

# %% [markdown]
# ---
# Problem 5
# ---------
#
# By construction, this dataset might contain a lot of overlapping samples, including training data that's also contained in the validation and test set! Overlap between training and test can skew the results if you expect to use your model in an environment where there is never an overlap, but are actually ok if you expect to see training samples recur when you use it.
# Measure how much overlap there is between training, validation and test samples.
#
# Optional questions:
# - What about near duplicates between datasets? (images that are almost identical)
# - Create a sanitized validation and test set, and compare your accuracy on those in subsequent assignments.
# ---

# %% [markdown]
# I'm going to check for exact matches by hashing each image as a pickle and placing each pickle as the key in a dict. The corresponding value will be the index of the first instance of that image in the 3d array `train_dataset`.
#
# I don't seem to have enough memory to hash all 200,000 images into a single dictionary, so i'll just take 10% and see if there are any images that are highly repeated and delete those. There may be a few duplicates left afterwards.

# %%
seen = {}
dupCounts = defaultdict(int)

for i, img in enumerate(train_dataset[0:20000]):
    serialized = pickle.dumps(img)
    if serialized in seen:
        print('image at index %s was already found at %s' % (i, seen[serialized]))
        dupCounts[seen[serialized]] += 1
    else:
        seen[serialized] = i
# Out:
# image at index 235 was already found at 128
# image at index 242 was already found at 128
# image at index 290 was already found at 128
# image at index 303 was already found at 128
# image at index 490 was already found at 128
# image at index 522 was already found at 128
# image at index 623 was already found at 128
# image at index 634 was already found at 128
# image at index 668 was already found at 128
# image at index 669 was already found at 128
# image at index 951 was already found at 128
# image at index 984 was already found at 128
# image at index 999 was already found at 128
# image at index 1001 was already found at 128
# image at index 1080 was already found at 128
# image at index 1361 was already found at 128
# image at index 1431 was already found at 128
# image at index 1440 was already found at 307
# image at index 1560 was already found at 128
# image at index 1871 was already found at 128
# image at index 1933 was already found at 128
# image at index 2021 was already found at 128
# image at index 2129 was already found at 128
# image at index 2192 was already found at 128
# image at index 2261 was already found at 128
# image at index 2303 was already found at 128
# image at index 2499 was already found at 128
# image at index 2513 was already found at 128
# image at index 2583 was already found at 128
# image at index 2643 was already found at 128
# image at index 2733 was already found at 128
# image at index 2898 was already found at 1018
# image at index 3070 was already found at 128
# image at index 3165 was already found at 128
# image at index 3169 was already found at 128
# image at index 3217 was already found at 128
# image at index 3254 was already found at 128
# image at index 3344 was already found at 128
# image at index 3346 was already found at 128
# image at index 3492 was already found at 1821
# image at index 3556 was already found at 128
# image at index 3786 was already found at 128
# image at index 3910 was already found at 3123
# image at index 3984 was already found at 128
# image at index 4038 was already found at 128
# image at index 4277 was already found at 128
# image at index 4424 was already found at 128
# image at index 4425 was already found at 128
# image at index 4438 was already found at 2939
# image at index 4706 was already found at 128
# image at index 4730 was already found at 128
# image at index 4819 was already found at 3960
# image at index 4935 was already found at 128
# image at index 4946 was already found at 128
# image at index 4991 was already found at 4616
# image at index 5017 was already found at 128
# image at index 5132 was already found at 1018
# image at index 5193 was already found at 128
# image at index 5194 was already found at 128
# image at index 5245 was already found at 128
# image at index 5325 was already found at 128
# image at index 5380 was already found at 128
# image at index 5463 was already found at 128
# image at index 5476 was already found at 128
# image at index 5496 was already found at 128
# image at index 5509 was already found at 128
# image at index 5518 was already found at 128
# image at index 5532 was already found at 128
# image at index 5641 was already found at 2581
# image at index 5695 was already found at 128
# image at index 5719 was already found at 128
# image at index 5727 was already found at 3450
# image at index 5762 was already found at 128
# image at index 5775 was already found at 128
# image at index 5827 was already found at 2955
# image at index 5852 was already found at 128
# image at index 5878 was already found at 128
# image at index 5910 was already found at 128
# image at index 5928 was already found at 4094
# image at index 6008 was already found at 128
# image at index 6024 was already found at 2840
# image at index 6092 was already found at 128
# image at index 6137 was already found at 485
# image at index 6139 was already found at 128
# image at index 6377 was already found at 5773
# image at index 6458 was already found at 128
# image at index 6499 was already found at 128
# image at index 6502 was already found at 128
# image at index 6519 was already found at 128
# image at index 6538 was already found at 128
# image at index 6580 was already found at 128
# image at index 6618 was already found at 128
# image at index 6623 was already found at 128
# image at index 6680 was already found at 128
# image at index 6711 was already found at 128
# image at index 6754 was already found at 128
# image at index 6769 was already found at 128
# image at index 6780 was already found at 6669
# image at index 6872 was already found at 128
# image at index 6920 was already found at 4315
# image at index 6989 was already found at 5628
# image at index 7037 was already found at 128
# image at index 7078 was already found at 3971
# image at index 7092 was already found at 128
# image at index 7132 was already found at 1876
# image at index 7303 was already found at 4490
# image at index 7570 was already found at 128
# image at index 7602 was already found at 128
# image at index 7644 was already found at 6262
# image at index 7822 was already found at 4616
# image at index 7882 was already found at 2816
# image at index 7907 was already found at 128
# image at index 7952 was already found at 2891
# image at index 7983 was already found at 128
# image at index 7994 was already found at 108
# image at index 8028 was already found at 128
# image at index 8085 was already found at 128
# image at index 8088 was already found at 3235
# image at index 8108 was already found at 128
# image at index 8123 was already found at 128
# image at index 8215 was already found at 2737
# image at index 8279 was already found at 128
# image at index 8290 was already found at 128
# image at index 8300 was already found at 2500
# image at index 8308 was already found at 4720
# image at index 8336 was already found at 3235
# image at index 8397 was already found at 128
# image at index 8462 was already found at 128
# image at index 8512 was already found at 128
# image at index 8531 was already found at 128
# image at index 8743 was already found at 7050
# image at index 8876 was already found at 128
# image at index 8924 was already found at 128
# image at index 8955 was already found at 128
# image at index 8984 was already found at 128
# image at index 8986 was already found at 128
# image at index 9164 was already found at 128
# image at index 9169 was already found at 128
# image at index 9181 was already found at 128
# image at index 9418 was already found at 1830
# image at index 9423 was already found at 128
# image at index 9428 was already found at 2517
# image at index 9443 was already found at 128
# image at index 9479 was already found at 128
# image at index 9509 was already found at 128
# image at index 9522 was already found at 1972
# image at index 9540 was already found at 128
# image at index 9541 was already found at 128
# image at index 9606 was already found at 128
# image at index 9637 was already found at 128
# image at index 9788 was already found at 8307
# image at index 9819 was already found at 6235
# image at index 9863 was already found at 1018
# image at index 9869 was already found at 128
# image at index 9968 was already found at 128
# image at index 10028 was already found at 784
# image at index 10053 was already found at 128
# image at index 10196 was already found at 175
# image at index 10221 was already found at 128
# image at index 10292 was already found at 4883
# image at index 10339 was already found at 128
# image at index 10498 was already found at 128
# image at index 10547 was already found at 128
# image at index 10665 was already found at 128
# image at index 10712 was already found at 4088
# image at index 10735 was already found at 128
# image at index 10747 was already found at 128
# image at index 10753 was already found at 128
# image at index 10812 was already found at 9691
# image at index 10825 was already found at 7857
# image at index 10859 was already found at 128
# image at index 10877 was already found at 128
# image at index 10904 was already found at 128
# image at index 10914 was already found at 4997
# image at index 10949 was already found at 128
# image at index 10953 was already found at 9862
# image at index 10959 was already found at 128
# image at index 10994 was already found at 128
# image at index 11066 was already found at 128
# image at index 11114 was already found at 2986
# image at index 11153 was already found at 2161
# image at index 11232 was already found at 128
# image at index 11239 was already found at 4616
# image at index 11275 was already found at 128
# image at index 11378 was already found at 128
# image at index 11421 was already found at 5296
# image at index 11857 was already found at 8560
# image at index 11866 was already found at 128
# image at index 11882 was already found at 2924
# image at index 11929 was already found at 128
# image at index 11935 was already found at 128
# image at index 11936 was already found at 128
# image at index 12048 was already found at 2038
# image at index 12054 was already found at 9695
# image at index 12068 was already found at 128
# image at index 12129 was already found at 128
# image at index 12444 was already found at 128
# image at index 12446 was already found at 128
# image at index 12492 was already found at 128
# image at index 12549 was already found at 128
# image at index 12580 was already found at 128
# image at index 12670 was already found at 978
# image at index 12700 was already found at 128
# image at index 12728 was already found at 128
# image at index 12738 was already found at 5094
# image at index 12866 was already found at 4197
# image at index 12889 was already found at 1018
# image at index 12949 was already found at 128
# image at index 12983 was already found at 12741
# image at index 12992 was already found at 128
# image at index 13045 was already found at 128
# image at index 13090 was already found at 128
# image at index 13102 was already found at 128
# image at index 13111 was already found at 128
# image at index 13144 was already found at 128
# image at index 13203 was already found at 128
# image at index 13230 was already found at 6235
# image at index 13242 was already found at 128
# image at index 13265 was already found at 128
# image at index 13275 was already found at 128
# image at index 13297 was already found at 10693
# image at index 13350 was already found at 9993
# image at index 13353 was already found at 9604
# image at index 13470 was already found at 128
# image at index 13501 was already found at 128
# image at index 13554 was already found at 128
# image at index 13626 was already found at 128
# image at index 13712 was already found at 128
# image at index 13728 was already found at 6551
# image at index 13731 was already found at 128
# image at index 13745 was already found at 12971
# image at index 13777 was already found at 128
# image at index 13859 was already found at 128
# image at index 13872 was already found at 128
# image at index 13878 was already found at 9802
# image at index 13896 was already found at 7767
# image at index 13909 was already found at 128
# image at index 13915 was already found at 128
# image at index 13948 was already found at 128
# image at index 14015 was already found at 10743
# image at index 14065 was already found at 128
# image at index 14088 was already found at 8874
# image at index 14128 was already found at 2958
# image at index 14140 was already found at 128
# image at index 14168 was already found at 128
# image at index 14206 was already found at 571
# image at index 14274 was already found at 128
# image at index 14295 was already found at 128
# image at index 14410 was already found at 11764
# image at index 14414 was already found at 10824
# image at index 14415 was already found at 128
# image at index 14430 was already found at 128
# image at index 14447 was already found at 128
# image at index 14492 was already found at 4997
# image at index 14529 was already found at 128
# image at index 14698 was already found at 13961
# image at index 14834 was already found at 5645
# image at index 14857 was already found at 11145
# image at index 14880 was already found at 128
# image at index 15110 was already found at 7524
# image at index 15199 was already found at 845
# image at index 15216 was already found at 128
# image at index 15385 was already found at 1226
# image at index 15398 was already found at 128
# image at index 15546 was already found at 128
# image at index 15548 was already found at 13816
# image at index 15552 was already found at 128
# image at index 15593 was already found at 128
# image at index 15663 was already found at 15113
# image at index 15865 was already found at 6046
# image at index 15964 was already found at 13413
# image at index 16041 was already found at 13660
# image at index 16077 was already found at 11789
# image at index 16092 was already found at 8412
# image at index 16128 was already found at 128
# image at index 16135 was already found at 6942
# image at index 16169 was already found at 128
# image at index 16204 was already found at 14400
# image at index 16231 was already found at 2541
# image at index 16485 was already found at 11481
# image at index 16536 was already found at 14302
# image at index 16550 was already found at 861
# image at index 16618 was already found at 3648
# image at index 16626 was already found at 15220
# image at index 16782 was already found at 12491
# image at index 16790 was already found at 128
# image at index 16808 was already found at 128
# image at index 16817 was already found at 128
# image at index 16859 was already found at 128
# image at index 16862 was already found at 15604
# image at index 16885 was already found at 128
# image at index 16888 was already found at 16146
# image at index 16903 was already found at 5024
# image at index 16929 was already found at 10991
# image at index 16960 was already found at 128
# image at index 16965 was already found at 128
# image at index 17103 was already found at 128
# image at index 17125 was already found at 16106
# image at index 17239 was already found at 128
# image at index 17252 was already found at 128
# image at index 17267 was already found at 6462
# image at index 17445 was already found at 5890
# image at index 17450 was already found at 128
# image at index 17531 was already found at 3960
# image at index 17615 was already found at 3138
# image at index 17673 was already found at 128
# image at index 17685 was already found at 128
# image at index 17725 was already found at 128
# image at index 17728 was already found at 9936
# image at index 17834 was already found at 15190
# image at index 17957 was already found at 7025
# image at index 17975 was already found at 128
# image at index 17990 was already found at 128
# image at index 18010 was already found at 6180
# image at index 18033 was already found at 3186
# image at index 18070 was already found at 128
# image at index 18111 was already found at 128
# image at index 18172 was already found at 11579
# image at index 18294 was already found at 128
# image at index 18327 was already found at 128
# image at index 18374 was already found at 12808
# image at index 18419 was already found at 6216
# image at index 18513 was already found at 17144
# image at index 18562 was already found at 128
# image at index 18567 was already found at 128
# image at index 18617 was already found at 128
# image at index 18670 was already found at 128
# image at index 18674 was already found at 128
# image at index 18681 was already found at 16429
# image at index 18829 was already found at 128
# image at index 18832 was already found at 15992
# image at index 18874 was already found at 11236
# image at index 18886 was already found at 4408
# image at index 18953 was already found at 9174
# image at index 19038 was already found at 11108
# image at index 19086 was already found at 128
# image at index 19105 was already found at 9003
# image at index 19130 was already found at 10632
# image at index 19178 was already found at 128
# image at index 19191 was already found at 16721
# image at index 19201 was already found at 1558
# image at index 19219 was already found at 128
# image at index 19225 was already found at 128
# image at index 19334 was already found at 128
# image at index 19346 was already found at 2541
# image at index 19359 was already found at 128
# image at index 19362 was already found at 128
# image at index 19411 was already found at 128
# image at index 19417 was already found at 128
# image at index 19426 was already found at 128
# image at index 19482 was already found at 128
# image at index 19503 was already found at 2652
# image at index 19544 was already found at 128
# image at index 19563 was already found at 6615
# image at index 19661 was already found at 16438
# image at index 19665 was already found at 128
# image at index 19760 was already found at 128
# image at index 19802 was already found at 3802
# image at index 19828 was already found at 128
# image at index 19834 was already found at 1558
# image at index 19857 was already found at 1670
# image at index 19908 was already found at 128
# image at index 19988 was already found at 128
# image at index 19997 was already found at 3842

# %%
highestCount = 0
mostFreq = None

for ind, count in dupCounts.iteritems():
    if count > highestCount:
        highestCount = count
        mostFreq = ind
        
print('the image at index %s is the most frequent, appearing %s times in the 20000 we looked at' % (mostFreq, highestCount))
# Out:
# the image at index 128 is the most frequent, appearing 232 times in the 20000 we looked at

# %% [markdown]
# #### Delete the duplicates of #128

# %%
target = pickle.dumps(train_dataset[mostFreq])
deleted = set()

for i in range(mostFreq + 1, len(train_dataset)):
    if (pickle.dumps(train_dataset[i]) == target):
        deleted.add(i)

print('removing %s images' % len(deleted))

clean_dataset = np.ndarray((len(train_dataset) - len(deleted), image_size, image_size), dtype=np.float32)

added = 0
for i, img in enumerate(train_dataset):
    if i not in deleted:
        clean_dataset[added, :, :] = img
        added += 1

print(clean_dataset.shape)
# Out:
# removing 2177 images
# (197823, 28, 28)

# %%
sample(clean_dataset, 233, 237)

# %% [markdown]
# ---
# Problem 6
# ---------
#
# Let's get an idea of what an off-the-shelf classifier can give you on this data. It's always good to check that there is something to learn, and that it's a problem that is not so trivial that a canned solution solves it.
#
# Train a simple model on this data using 50, 100, 1000 and 5000 training samples. Hint: you can use the LogisticRegression model from sklearn.linear_model.
#
# Optional question: train an off-the-shelf model on all the data!
#
# ---
